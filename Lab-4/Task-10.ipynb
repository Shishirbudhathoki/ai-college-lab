# %% [markdown]
# #### Save the trained PyTorch model, reload it, and verify that predictions match.

# %%
import numpy as np
import torch
from torch import nn
import matplotlib.pyplot as plt

np.random.seed(42)

x1 = np.arange(0, 1, 0.02)
x2 = np.random.rand(len(x1))

# Combine into one matrix
X = np.column_stack((x1, x2))

# y = 5*x1 + 2*x2 + 3
noise = np.random.normal(0, 0.1, len(x1))
y = 5*x1 + 2*x2 + 3 + noise

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.3,random_state=42)
X_train, y_train = torch.from_numpy(X_train).float(), torch.from_numpy(y_train).float().unsqueeze(1)
X_test, y_test = torch.from_numpy(X_test).float(), torch.from_numpy(y_test).float().unsqueeze(1)

# %%
class MultipleLinearRegression(nn.Module):
    def __init__(self):
        super().__init__()

        self.linear = nn.Linear(in_features=2,out_features=1)

    def forward(self, x):
        return self.linear(x)

# %%
model = MultipleLinearRegression()
model.load_state_dict(torch.load("multiple_linear_model.pth"))
with torch.inference_mode():
    loaded_predictions = model(X_test)

# %%
print(loaded_predictions)
# Out:
# tensor([[4.8958],
#         [7.6603],
#         [7.1680],
#         [8.6186],
#         [5.8444],
#         [8.6695],
#         [6.0392],
#         [7.0542],
#         [6.3240],
#         [5.5834],
#         [5.9760],
#         [3.9814],
#         [6.8345],
#         [5.1804],
#         [4.7267]])

# %%
print(y_test)
# Out:
# tensor([[4.7858],
#         [7.5815],
#         [7.2512],
#         [8.7749],
#         [5.7186],
#         [8.8404],
#         [5.9921],
#         [7.2060],
#         [6.3265],
#         [5.5800],
#         [5.7972],
#         [3.5642],
#         [6.8654],
#         [5.0366],
#         [4.4672]])

# %%
# PyTorch's autograd and optimizers simplify the training process by automatically calculating gradients and updating model parameters. They reduce coding effort and errors and make it practical to train complex neural networks with a large number of parameters.
